# %% [markdown]
# # Functions
#     - Functions are block of code that don some specific task.
#     - Whenever wee need to do the task we call the function.
#     - It reduces the code
#     - It make code easier to debug the errors

# %% [markdown]
# # Python Functions
#    - print()
#    - input()
#    - len()
#    - type()
#    - etc.
# # Class Functions:
#    - list. function
#    - dictionary. functions
#    - string .function
#    - etc.
# # User Defined Functions
#    - Function we define to perform some specific task.

# %%
# function definition
def say_salam():
    print("Assalam.o.Alaikum!")

# %%
# function call / invoke function
say_salam()
# Out:
# Assalam.o.Alaikum!

# %%
def add():
    a=10
    b=20
    res = a+b
    print(res)

# %%
add()
# Out:
# 30

# %% [markdown]
# #### Passing information to a function
#    - argument     values provided
#    - parameter    variables that store provoided values (arguments)

# %%
# function definition
def say_salam(name): # parameter
    print(f"Mr.{name}, Assalam.o.Alaikum!")

# %%
say_salam()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2616\3078760585.py in <module>
# ----> 1 say_salam()
#
# TypeError: say_salam() missing 1 required positional argument: 'name'

# %%
say_salam('Waqas')# argument
# Out:
# Mr.Waqas, Assalam.o.Alaikum!

# %%
say_salam('Yasir')# argument
# Out:
# Mr.Yasir, Assalam.o.Alaikum!

# %%
say_salam('Johan')
# Out:
# Mr.Johan, Assalam.o.Alaikum!

# %%
def add(a,b):
    res = a+b
    print(res)

# %%
add(1,2)
# Out:
# 3

# %%
add(23 ,45)
# Out:
# 68

# %%
add(5,7)
# Out:
# 12

# %%
add(8,9)
# Out:
# 17

# %%
def make_call(lst):
    for name in lst:
        print(f"Calling!...Mr.{name}, Assalam.o.Alaikum!")

# %%
make_call(['asad','nasir','waqas','kamran'])
# Out:
# Calling!...Mr.asad, Assalam.o.Alaikum!
# Calling!...Mr.nasir, Assalam.o.Alaikum!
# Calling!...Mr.waqas, Assalam.o.Alaikum!
# Calling!...Mr.kamran, Assalam.o.Alaikum!

# %%
# make a fnction that takes the list of numbers.
# function will print the sqaure of numbers greater than 10
# function will print the cube of number less than 10.

# %%
def square_cube(numbers):
    for i in numbers:
        if i >10:
            print(f"{i} it's suqare is: {i**2}")
        else:
            print(f"{i} it's cube is: {i**3}")

# %%
square_cube([2,4,5,7,12,13,20,15])
# Out:
# 2 it's cube is: 8
# 4 it's cube is: 64
# 5 it's cube is: 125
# 7 it's cube is: 343
# 12 it's suqare is: 144
# 13 it's suqare is: 169
# 20 it's suqare is: 400
# 15 it's suqare is: 225

# %% [raw]
# Write a function that takes a string input and anylyze
# how many words are in string
# how many characters  are in string
# how many sentences in string
# how many capital letters are in string
# how many numbers are in string
# how many spaces are in string
# how many vowels are in string
# how many punctuations are in string

# %%
paragraph = """What this handout is about. This handout will help you understand how paragraphs are formed, how to develop stronger paragraphs, and how to completely and clearly express your ideas.
What is a paragraph.
Paragraphs are the building blocks of papers. Many students define paragraphs in terms of length: a paragraph is a group of at least five sentences, a paragraph is half a page long, etc. In reality, though, the unity and coherence of ideas among sentences is what constitutes a paragraph. A paragraph is defined as “a group of sentences or a single sentence that forms a unit” (Lunsford and Connors 116). Length and appearance do not determine whether a section in a paper is a paragraph. For instance, in some styles of writing, particularly journalistic styles, a paragraph can be just one sentence long. Ultimately, a paragraph is a sentence or group of sentences that support one main idea. In this handout, we will refer to this as the “controlling idea,” because it controls what happens in the rest of the paragraph.
How do I decide what to put in a paragraph.
Before you can begin to determine what the composition of a particular paragraph will be, you must first decide on a working thesis for your paper. What is the most important idea that you are trying to convey to your reader? The information in each paragraph must be related to that idea. In other words, your paragraphs should remind your reader that there is a recurrent relationship between your thesis and the information in each paragraph. A working thesis functions like a seed from which your paper, and your ideas, will grow. The whole process is an organic one—a natural progression from a seed to a full-blown paper where there are direct, familial relationships between all of the ideas in the paper.
The decision about what to put into your paragraphs begins with the germination of a seed of ideas; this “germination process” is better known as brainstorming. There are many techniques for brainstorming; whichever one you choose, this stage of paragraph development cannot be skipped. Building paragraphs can be like building a skyscraper: there must be a well-planned foundation that supports what you are building. Any cracks, inconsistencies, or other corruptions of the foundation can cause your whole paper to crumble"""

# %%
def text_analyser(txt):
    vowels = 'aeiouAEIOU'
    punctuations="""!"#$%&'()*+,-./:;<=>?@[\]^_{|}~`'"""
    character_count = 0
    words_count = len(txt.split(" "))
    sentence_count = len(txt.split("."))-1
    upper_count = 0
    digit_count=0
    space_count = 0    
    vowels_count=0    
    punctuations_count =0
    for char in txt:
        if char.isalpha():
            character_count+=1
        if char.isupper():
            upper_count+=1
        if char.isdigit():
            digit_count+=1
        if char.isspace():
            space_count+=1
        if char in vowels:
            vowels_count+=1
        if char in punctuations:
            punctuations_count+=1
            
    print(f"""       
    words are in string          :  {words_count}
    characters  are in string    :  {character_count}
    sentences in string          :  {sentence_count}         
    capital letters are in string:  {upper_count}
    numbers are in string        :  {digit_count} 
    spaces are in string         :  {space_count}
    vowels are in string         :  {vowels_count}
    punctuations are in string   :  {punctuations_count}
    """)

# %%
p = "How do! I decide. 45 what to put 67 in a, paragrapht?"
text_analyser(p)
# Out:
#
#     words are in string          :  12
#     characters  are in string    :  34
#     sentences in string          :  1
#     capital letters are in string:  2
#     numbers are in string        :  4
#     spaces are in string         :  11
#     vowels are in string         :  14
#     punctuations are in string   :  4

# %%
("How do I decide 45. what to? Put 67 in a. paragrapht. hello."split("."))
# Out:
# ['How do I decide 45', ' what to? Put 67 in a', ' paragrapht', ' hello', '']

# %%
text_analyser(paragraph)
# Out:
#
#     words are in string          :  380
#     characters  are in string    :  1865
#     sentences in string          :  17
#     capital letters are in string:  25
#     numbers are in string        :  3
#     spaces are in string         :  388
#     vowels are in string         :  724
#     punctuations are in string   :  48
