# %% [markdown]
# # While Loop

# %%
amount=10000
while amount>0:
  print(amount, "Do Shopping")
  amount-=1000
# Out:
# 10000 Do Shopping
# 9000 Do Shopping
# 8000 Do Shopping
# 7000 Do Shopping
# 6000 Do Shopping
# 5000 Do Shopping
# 4000 Do Shopping
# 3000 Do Shopping
# 2000 Do Shopping
# 1000 Do Shopping

# %%
count=0
while count<=10:
  print(count, "count")
  count+=1
# Out:
# 0 count
# 1 count
# 2 count
# 3 count
# 4 count
# 5 count
# 6 count
# 7 count
# 8 count
# 9 count
# 10 count

# %%
num = int(input("Enter a number (n):"))
sum_n = 0
counter = 1
while counter <= num:
    sum_n += counter
    counter += 1
print(f"The sum of the first {num} natural numbers is: {sum_n}")
# Out:
# Enter a number (n):12
# The sum of the first 12 natural numbers is: 78

# %%
number = 0
while number<100:
  print(f"I am {number}")
  number+=10
# Out:
# I am 0
# I am 10
# I am 20
# I am 30
# I am 40
# I am 50
# I am 60
# I am 70
# I am 80
# I am 90

# %%
n = 0
while n <= 100:
  print (f"I am {n}")
  n+=25
# Out:
# I am 0
# I am 25
# I am 50
# I am 75
# I am 100

# %%
# run a while loop 10 times every time while doubles the number
num=1
while num<=10:
  print(f"Double of number {num} is: {num*2}")
  num+=1
# Out:
# Double of number 1 is: 2
# Double of number 2 is: 4
# Double of number 3 is: 6
# Double of number 4 is: 8
# Double of number 5 is: 10
# Double of number 6 is: 12
# Double of number 7 is: 14
# Double of number 8 is: 16
# Double of number 9 is: 18
# Double of number 10 is: 20

# %%
# run a while loop 10 times every time if number is even double it and if its odd triple it
num=0
while num<=10:
  if num%2==0:
      print(f"Double of number {num} is: {num*2}")
  else:
      print(f"Double of number {num} is: {num*3}")
  num+=1
# Out:
# Double of number 0 is: 0
# Double of number 1 is: 3
# Double of number 2 is: 4
# Double of number 3 is: 9
# Double of number 4 is: 8
# Double of number 5 is: 15
# Double of number 6 is: 12
# Double of number 7 is: 21
# Double of number 8 is: 16
# Double of number 9 is: 27
# Double of number 10 is: 20

# %%
num = 0
while num <= 10:
  if num%2==0:
      print(f"Double of number {num} is: {num*2}")
  else:
      print(f"triple of number {num} is: {num*3}")
  num+=1
# Out:
# Double of number 0 is: 0
# triple of number 1 is: 3
# Double of number 2 is: 4
# triple of number 3 is: 9
# Double of number 4 is: 8
# triple of number 5 is: 15
# Double of number 6 is: 12
# triple of number 7 is: 21
# Double of number 8 is: 16
# triple of number 9 is: 27
# Double of number 10 is: 20

# %%
# generate square of numbers 1-10 using for looop then while loop
for n in range(1,11):
  print(f"Square of number {n} is: {n**2}")
# Out:
# Square of number 1 is: 1
# Square of number 2 is: 4
# Square of number 3 is: 9
# Square of number 4 is: 16
# Square of number 5 is: 25
# Square of number 6 is: 36
# Square of number 7 is: 49
# Square of number 8 is: 64
# Square of number 9 is: 81
# Square of number 10 is: 100

# %%
num = 1
while num<=10:
  print(f"Square of number {num} is: {num**2}")
  num+=1
# Out:
# Square of number 1 is: 1
# Square of number 2 is: 4
# Square of number 3 is: 9
# Square of number 4 is: 16
# Square of number 5 is: 25
# Square of number 6 is: 36
# Square of number 7 is: 49
# Square of number 8 is: 64
# Square of number 9 is: 81
# Square of number 10 is: 100

# %%
print ("Using for loop:")
for n in range(1,11):
  print(f"Square of number {n} is: {n**2}")

print ("Using while loop:")
num = 1
while num<=10:
  print(f"Square of number {num} is: {num**2}")
  num+=1
# Out:
# Using for loop:
# Square of number 1 is: 1
# Square of number 2 is: 4
# Square of number 3 is: 9
# Square of number 4 is: 16
# Square of number 5 is: 25
# Square of number 6 is: 36
# Square of number 7 is: 49
# Square of number 8 is: 64
# Square of number 9 is: 81
# Square of number 10 is: 100
# Using while loop:
# Square of number 1 is: 1
# Square of number 2 is: 4
# Square of number 3 is: 9
# Square of number 4 is: 16
# Square of number 5 is: 25
# Square of number 6 is: 36
# Square of number 7 is: 49
# Square of number 8 is: 64
# Square of number 9 is: 81
# Square of number 10 is: 100

# %% [markdown]
# # **Functions**

# %%
id("abc")
# Out:
# 10789312

# %%
# declare
def say_salam():
  print("Assalam-u-Alaikum!")

# %%
say_salam()
# Out:
# Assalam-u-Alaikum!

# %%
def lol():
  print("League Of Legends")

# %%
lol()
# Out:
# League Of Legends

# %%
def meow():
  print("Meow! GOP GOP GOP GOP")

# %%
meow()
# Out:
# Meow! GOP GOP GOP GOP

# %%
def greeting():
  print("Good Morning!")

# %%
greeting()
# Out:
# Good Morning!

# %%
def say_salam(name): #parameter
  print(f"Assalam-u-Alaikum! {name}")

# %%
say_salam("Momin") #argument
# Out:
# Assalam-u-Alaikum! Momin

# %%
say_salam("Ali")
# Out:
# Assalam-u-Alaikum! Ali

# %%
def calculator(num1,num2,operation):
  if operation=="+":
    print(f"Addition of {num1} and {num2} is: {num1+num2}")
  elif operation=="-":
    print(f"Subtraction of {num1} and {num2} is: {num1-num}")
  elif operation=="*":
    print(f"Multiplication of {num1} and {num2} is: {num1*num2}")
  elif operation=="/":
    print(f"Division of {num1} and {num2} is: {num1/num2}")
  else:
    print("Invalid operation")

# %%
calculator(12,34,'/')
# Out:
# Division of 12 and 34 is: 0.35294117647058826

# %%
def odd_even_checker(num1):
  if num1%2==0:
    print(f"{num1} is even.")
  else:
    print(f"{num1} is odd.")

# %%
odd_even_checker(12)
# Out:
# 12 is even.

# %%
odd_even_checker(121121)
# Out:
# 121121 is odd.

# %%
# Write a function that takes the name of the user and tells:

# %%
def name_analyzer(name):
  vowels = ['a','e','i','o','u','A','E','I','O','U']
  vowels_count = 0
  upper_count = 0
  lower_count = 0
  for char in name:
    if char in vowels:
      vowels_count+=1
    if char.isupper():
      upper_count=+1
    if char.islower():
      lower_count+=1
  print(f"""
         Vowels: {vowels_count}
         upper : {upper_count}
         lower : {lower_count}""")

# %%
name_analyzer("Yousuf Khaskheli")
# Out:
#          Vowels: 6
#          upper : 1
#          lower : 13
