# %% [markdown]
# # Four Pillars of OOPs
# 1. Encapsulation
#
# 2. Inheritance
#
# 3. Polymorphism
#
# 4. Abstraction

# %% [markdown]
# # Encapsulation
#     - blinding data with methods

# %%
class Student:
    def __init__(self, name, roll, course, email, marks):
        self.name = name
        self.roll = roll
        self.course = course
        self.email = email
        self.marks = marks

    def show_profile(self):
        print("Student Profile")
        print(f"Name: {self.name}")
        print(f"Roll No: {self.roll}")
        print(f"Course: {self.course}")
        print(f"Email: {self.email}")
        print(f"Marks: {self.marks}")

# %%
s1 = Student('Asad',2241,'Data science','asad@gmail.com',93)

# %%
s1.show_profile()
# Out:
# Student Profile
# Name: Asad
# Roll No: 2241
# Course: Data science
# Email: asad@gmail.com
# Marks: 93

# %%
s1.email
# Out:
# 'asad@gmail.com'

# %%
s1.course
# Out:
# 'Data science'

# %%
class Student:
    def __init__(self, name, roll, course, email, marks):
        # Instance Variables
        self.name = name
        self.roll = roll
        self.course = course
        self.email = email
        self.marks = marks

    def show_profile(self):
        print("Student Profile")
        print(f"Name: {self.name}")
        print(f"Roll No: {self.roll}")
        print(f"Course: {self.course}")
        print(f"Email: {self.email}")
        print(f"Marks: {self.marks}")
    def get_marks(self):
        return self.marks
    def set_marks(self,new_marks):
        if (new_marks>=0) and (new_marks<=100):
            self.marks = new_marks
        else:
            return 'Invalid marks'

# %%
s1 = Student('Amir',8632,'Data science','amir@gmail.com',62)

# %%
s1.get_marks()
# Out:
# 62

# %%
s1.set_marks(102)
# Out:
# 'Invalid marks'

# %%
s1.set_marks(89)

# %%
s1.get_marks()
# Out:
# 89

# %%
s1.show_profile()
# Out:
# Student Profile
# Name: Amir
# Roll No: 8632
# Course: Data science
# Email: amir@gmail.com
# Marks: 89

# %% [markdown]
# # Access Modifiers:
#     - Public
#     - Private
#     - Protected

# %%
class Student:
    def __init__(self, name, roll, course, email, marks):
        # Instance Variables
        self.name = name
        self.roll = roll
        self.course = course
        self.email = email
        self.marks = marks

    def show_profile(self):
        print("Student Profile")
        print(f"Name: {self.name}")
        print(f"Roll No: {self.roll}")
        print(f"Course: {self.course}")
        print(f"Email: {self.email}")
        print(f"Marks: {self.marks}")
    def get_marks(self):
        return self.marks
    def set_marks(self,new_marks):
        if (new_marks>=0) and (new_marks<=100):
            self.marks = new_marks
        else:
            return 'Invalid marks'

# %%
s1 = Student('Amir',8632,'Data science','amir@gmail.com',87)

# %%
s1.marks
# Out:
# 87

# %%
class Student:
    def __init__(self, name, roll, course, email, marks):
        # Instance Variables
        self.name = name
        self.roll = roll
        self.course = course
        self.email = email
        # protected Instance Variables
        self._marks = marks

    def show_profile(self):
        print("Student Profile")
        print(f"Name: {self.name}")
        print(f"Roll No: {self.roll}")
        print(f"Course: {self.course}")
        print(f"Email: {self.email}")
        print(f"Marks: {self._marks}")
    def get_marks(self):
        return self._marks
    def set_marks(self,new_marks):
        if (new_marks>=0) and (new_marks<=100):
            self._marks = new_marks
        else:
            return 'Invalid marks'

# %%
s1 = Student('Amir',8632,'Data science','amir@gmail.com',87)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\SMIT\Desktop\python with me

# %%
class Patient:

    def __init__(self, patient_id, name, age, gender,blood_group, disease, doctor, phone, address):

        self.patient_id = patient_id
        self.name = name
        self.age = age
        self.gender = gender
        self.blood_group = blood_group
        self.disease = disease
        self.doctor = doctor
        self.phone = phone
        self.address = address

    # Show Full Patient Profile
    def show_profile(self):

        print("===== Patient Profile =====")

        print(f"Patient ID   : {self.patient_id}")
        print(f"Name         : {self.name}")
        print(f"Age          : {self.age}")
        print(f"Gender       : {self.gender}")
        print(f"Blood Group  : {self.blood_group}")
        print(f"Disease      : {self.disease}")
        print(f"Doctor       : {self.doctor}")
        print(f"Phone Number : {self.phone}")
        print(f"Address      : {self.address}")

    # Update Disease
    def update_disease(self, new_disease):
        self.disease = new_disease
        print("Disease Updated Successfully")

    # Show Blood Group
    def show_blood_group(self):
        print(f"Blood Group: {self.blood_group}")

# %%
p1 = Patient(176,'Hamza',51,'Male','A negetive','Dengue','Syed Amir Shah','+923214687908','Jamshed town, karachi')

# %%
p1.show_profile()
# Out:
# ===== Patient Profile =====
# Patient ID   : 176
# Name         : Hamza
# Age          : 51
# Gender       : Male
# Blood Group  : A negetive
# Disease      : Dengue
# Doctor       : Syed Amir Shah
# Phone Number : +923214687908
# Address      : Jamshed town, karachi

# %%
p1.patient_id
# Out:
# 176

# %%
p1.name
# Out:
# 'Hamza'
