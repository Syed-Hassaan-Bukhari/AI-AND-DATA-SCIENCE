# %% [markdown]
# # Data Cleaning and Preparation
#      - Handlinh missing data
#      - Duplicate data
#      - Wrong data types
#      - Outfier values identity and removal

# %% [markdown]
# ### Handling missing data
#       - drop the data
#       - Handling the missing data

# %%
import pandas as pd
# Out:
# C:\Users\SMIT\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\SMIT\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('employee.xlsx')

# %%
data
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        0    1101     Manager    Accounts  50.0  200000.0
# 1        1    1107     Officer          IT  30.0   80000.0
# 2        2    1203     Officer          HR  28.0       NaN
# 3        3    1005     Manager          HR  45.0  120000.0
# 4        4    2123  Office Boy    Accounts  27.0   45000.0
# 5        5    2451  Accountant         NaN  34.0  100000.0
# 6        6    1111  Accountant    Accounts   NaN  110000.0
# 7        7    1001     Officer          IT  25.0   75000.0
# 8        8    1234     Manager          IT  23.0       NaN
# 9        9    2156    Engineer  Production  45.0   89000.0
# 10      10    6543     Officer  Production  29.0  100000.0
# 11      11    3214  Accountant     Account  49.0  123000.0
# 12      12    2156    Engineer  Production  45.0   89000.0
# 13      13    1098     Officer          IT  25.0  100000.0
# 14      14    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.shape
# Out:
# (26, 6)

# %%
data.sample(5)
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 4        4    2123  Office Boy    Accounts  27.0   45000.0
# 3        3    1005     Manager          HR  45.0  120000.0
# 20      20    6543     Officer  Production  29.0  100000.0
# 11      11    3214  Accountant     Account  49.0  123000.0
# 7        7    1001     Officer          IT  25.0   75000.0

# %%
data.head()
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       0    1101     Manager   Accounts  50.0  200000.0
# 1       1    1107     Officer         IT  30.0   80000.0
# 2       2    1203     Officer         HR  28.0       NaN
# 3       3    1005     Manager         HR  45.0  120000.0
# 4       4    2123  Office Boy   Accounts  27.0   45000.0

# %%
data.columns
# Out:
# Index(['Serial', 'Emp_ID', 'Designation', 'Department', 'Age', 'Salary'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=26, step=1)

# %%
data.shape
# Out:
# (26, 6)

# %%
data.tail()
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 21      21    3214  Accountant     Account  49.0  123000.0
# 22      22    2156    Engineer  Production  45.0   89000.0
# 23      23    1098     Officer          IT  25.0  100000.0
# 24      24    2156    Engineer  Production  45.0   89000.0
# 25      25    2123  Office Boy    Accounts  27.0   45000.0

# %%
data.head(7)
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       0    1101     Manager   Accounts  50.0  200000.0
# 1       1    1107     Officer         IT  30.0   80000.0
# 2       2    1203     Officer         HR  28.0       NaN
# 3       3    1005     Manager         HR  45.0  120000.0
# 4       4    2123  Office Boy   Accounts  27.0   45000.0
# 5       5    2451  Accountant        NaN  34.0  100000.0
# 6       6    1111  Accountant   Accounts   NaN  110000.0

# %%
data.sample(5)
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 10      10    6543     Officer  Production  29.0  100000.0
# 24      24    2156    Engineer  Production  45.0   89000.0
# 3        3    1005     Manager          HR  45.0  120000.0
# 17      17    2123  Office Boy    Accounts  27.0   45000.0
# 18      18    1005     Manager          HR  45.0  120000.0

# %%
data.describe()
# Out:
#           Serial       Emp_ID        Age         Salary
# count  26.000000    26.000000  25.000000      23.000000
# mean   12.500000  2166.692308  35.000000   94173.913043
# std     7.648529  1463.539074   9.746794   33714.917354
# min     0.000000  1001.000000  23.000000   45000.000000
# 25%     6.250000  1108.000000  27.000000   84500.000000
# 50%    12.500000  2123.000000  30.000000   90000.000000
# 75%    18.750000  2156.000000  45.000000  105000.000000
# max    25.000000  6543.000000  50.000000  200000.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Serial       26 non-null     int64
#  1   Emp_ID       26 non-null     int64
#  2   Designation  26 non-null     object
#  3   Department   24 non-null     object
#  4   Age          25 non-null     float64
#  5   Salary       23 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.3+ KB

# %%
data.isna().sum()
# Out:
# Serial         0
# Emp_ID         0
# Designation    0
# Department     2
# Age            1
# Salary         3
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Serial         0
# Emp_ID         0
# Designation    0
# Department     2
# Age            1
# Salary         3
# dtype: int64

# %%
data.notna().sum()
# Out:
# Serial         26
# Emp_ID         26
# Designation    26
# Department     24
# Age            25
# Salary         23
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Serial         26
# Emp_ID         26
# Designation    26
# Department     24
# Age            25
# Salary         23
# dtype: int64

# %%
data.notnull()
# Out:
#     Serial  Emp_ID  Designation  Department    Age  Salary
# 0     True    True         True        True   True    True
# 1     True    True         True        True   True    True
# 2     True    True         True        True   True   False
# 3     True    True         True        True   True    True
# 4     True    True         True        True   True    True
# 5     True    True         True       False   True    True
# 6     True    True         True        True  False    True
# 7     True    True         True        True   True    True
# 8     True    True         True        True   True   False
# 9     True    True         True        True   True    True
# 10    True    True         True        True   True    True
# 11    True    True         True        True   True    True
# 12    True    True         True        True   True    True
# 13    True    True         True        True   True    True
# 14    True    True         True        True   True    True
# ...

# %%
data.dropna(axis=0)
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        0    1101     Manager    Accounts  50.0  200000.0
# 1        1    1107     Officer          IT  30.0   80000.0
# 3        3    1005     Manager          HR  45.0  120000.0
# 4        4    2123  Office Boy    Accounts  27.0   45000.0
# 7        7    1001     Officer          IT  25.0   75000.0
# 9        9    2156    Engineer  Production  45.0   89000.0
# 10      10    6543     Officer  Production  29.0  100000.0
# 11      11    3214  Accountant     Account  49.0  123000.0
# 12      12    2156    Engineer  Production  45.0   89000.0
# 13      13    1098     Officer          IT  25.0  100000.0
# 14      14    2912     Officer          IT  31.0   90000.0
# 16      16    2156    Engineer  Production  45.0   89000.0
# 17      17    2123  Office Boy    Accounts  27.0   45000.0
# 18      18    1005     Manager          HR  45.0  120000.0
# 19      19    2123  Office Boy    Accounts  27.0   45000.0
# ...

# %%
data
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        0    1101     Manager    Accounts  50.0  200000.0
# 1        1    1107     Officer          IT  30.0   80000.0
# 2        2    1203     Officer          HR  28.0       NaN
# 3        3    1005     Manager          HR  45.0  120000.0
# 4        4    2123  Office Boy    Accounts  27.0   45000.0
# 5        5    2451  Accountant         NaN  34.0  100000.0
# 6        6    1111  Accountant    Accounts   NaN  110000.0
# 7        7    1001     Officer          IT  25.0   75000.0
# 8        8    1234     Manager          IT  23.0       NaN
# 9        9    2156    Engineer  Production  45.0   89000.0
# 10      10    6543     Officer  Production  29.0  100000.0
# 11      11    3214  Accountant     Account  49.0  123000.0
# 12      12    2156    Engineer  Production  45.0   89000.0
# 13      13    1098     Officer          IT  25.0  100000.0
# 14      14    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.dropna(axis=1)
# Out:
#     Serial  Emp_ID Designation
# 0        0    1101     Manager
# 1        1    1107     Officer
# 2        2    1203     Officer
# 3        3    1005     Manager
# 4        4    2123  Office Boy
# 5        5    2451  Accountant
# 6        6    1111  Accountant
# 7        7    1001     Officer
# 8        8    1234     Manager
# 9        9    2156    Engineer
# 10      10    6543     Officer
# 11      11    3214  Accountant
# 12      12    2156    Engineer
# 13      13    1098     Officer
# 14      14    2912     Officer
# 15      15    1222     Officer
# 16      16    2156    Engineer
# 17      17    2123  Office Boy
# 18      18    1005     Manager
# 19      19    2123  Office Boy
# 20      20    6543     Officer
# 21      21    3214  Accountant
# 22      22    2156    Engineer
# 23      23    1098     Officer
# 24      24    2156    Engineer
# 25      25    2123  Office Boy

# %%
data.dropna(axis=1, how='all')
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        0    1101     Manager    Accounts  50.0  200000.0
# 1        1    1107     Officer          IT  30.0   80000.0
# 2        2    1203     Officer          HR  28.0       NaN
# 3        3    1005     Manager          HR  45.0  120000.0
# 4        4    2123  Office Boy    Accounts  27.0   45000.0
# 5        5    2451  Accountant         NaN  34.0  100000.0
# 6        6    1111  Accountant    Accounts   NaN  110000.0
# 7        7    1001     Officer          IT  25.0   75000.0
# 8        8    1234     Manager          IT  23.0       NaN
# 9        9    2156    Engineer  Production  45.0   89000.0
# 10      10    6543     Officer  Production  29.0  100000.0
# 11      11    3214  Accountant     Account  49.0  123000.0
# 12      12    2156    Engineer  Production  45.0   89000.0
# 13      13    1098     Officer          IT  25.0  100000.0
# 14      14    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.dropna(axis=1, thresh=24)
# Out:
#     Serial  Emp_ID Designation  Department   Age
# 0        0    1101     Manager    Accounts  50.0
# 1        1    1107     Officer          IT  30.0
# 2        2    1203     Officer          HR  28.0
# 3        3    1005     Manager          HR  45.0
# 4        4    2123  Office Boy    Accounts  27.0
# 5        5    2451  Accountant         NaN  34.0
# 6        6    1111  Accountant    Accounts   NaN
# 7        7    1001     Officer          IT  25.0
# 8        8    1234     Manager          IT  23.0
# 9        9    2156    Engineer  Production  45.0
# 10      10    6543     Officer  Production  29.0
# 11      11    3214  Accountant     Account  49.0
# 12      12    2156    Engineer  Production  45.0
# 13      13    1098     Officer          IT  25.0
# 14      14    2912     Officer          IT  31.0
# 15      15    1222     Officer         NaN  25.0
# 16      16    2156    Engineer  Production  45.0
# 17      17    2123  Office Boy    Accounts  27.0
# ...

# %%
data.dropna(axis=1, thresh=23)
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        0    1101     Manager    Accounts  50.0  200000.0
# 1        1    1107     Officer          IT  30.0   80000.0
# 2        2    1203     Officer          HR  28.0       NaN
# 3        3    1005     Manager          HR  45.0  120000.0
# 4        4    2123  Office Boy    Accounts  27.0   45000.0
# 5        5    2451  Accountant         NaN  34.0  100000.0
# 6        6    1111  Accountant    Accounts   NaN  110000.0
# 7        7    1001     Officer          IT  25.0   75000.0
# 8        8    1234     Manager          IT  23.0       NaN
# 9        9    2156    Engineer  Production  45.0   89000.0
# 10      10    6543     Officer  Production  29.0  100000.0
# 11      11    3214  Accountant     Account  49.0  123000.0
# 12      12    2156    Engineer  Production  45.0   89000.0
# 13      13    1098     Officer          IT  25.0  100000.0
# 14      14    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.dropna(axis=1, thresh=25)
# Out:
#     Serial  Emp_ID Designation   Age
# 0        0    1101     Manager  50.0
# 1        1    1107     Officer  30.0
# 2        2    1203     Officer  28.0
# 3        3    1005     Manager  45.0
# 4        4    2123  Office Boy  27.0
# 5        5    2451  Accountant  34.0
# 6        6    1111  Accountant   NaN
# 7        7    1001     Officer  25.0
# 8        8    1234     Manager  23.0
# 9        9    2156    Engineer  45.0
# 10      10    6543     Officer  29.0
# 11      11    3214  Accountant  49.0
# 12      12    2156    Engineer  45.0
# 13      13    1098     Officer  25.0
# 14      14    2912     Officer  31.0
# 15      15    1222     Officer  25.0
# 16      16    2156    Engineer  45.0
# 17      17    2123  Office Boy  27.0
# 18      18    1005     Manager  45.0
# 19      19    2123  Office Boy  27.0
# 20      20    6543     Officer  29.0
# 21      21    3214  Accountant  49.0
# 22      22    2156    Engineer  45.0
# 23      23    1098     Officer  25.0
# ...

# %%
data.shape
# Out:
# (26, 6)

# %%
data.shape[0]
# Out:
# 26

# %%
int(data.shape[0]*0.90)
# Out:
# 23

# %%
data.dropna(axis=1, thresh=int(data.shape[0]*0.90))
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        0    1101     Manager    Accounts  50.0  200000.0
# 1        1    1107     Officer          IT  30.0   80000.0
# 2        2    1203     Officer          HR  28.0       NaN
# 3        3    1005     Manager          HR  45.0  120000.0
# 4        4    2123  Office Boy    Accounts  27.0   45000.0
# 5        5    2451  Accountant         NaN  34.0  100000.0
# 6        6    1111  Accountant    Accounts   NaN  110000.0
# 7        7    1001     Officer          IT  25.0   75000.0
# 8        8    1234     Manager          IT  23.0       NaN
# 9        9    2156    Engineer  Production  45.0   89000.0
# 10      10    6543     Officer  Production  29.0  100000.0
# 11      11    3214  Accountant     Account  49.0  123000.0
# 12      12    2156    Engineer  Production  45.0   89000.0
# 13      13    1098     Officer          IT  25.0  100000.0
# 14      14    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.dropna(axis=0, thresh=int(data.shape[1]*0.90))
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        0    1101     Manager    Accounts  50.0  200000.0
# 1        1    1107     Officer          IT  30.0   80000.0
# 2        2    1203     Officer          HR  28.0       NaN
# 3        3    1005     Manager          HR  45.0  120000.0
# 4        4    2123  Office Boy    Accounts  27.0   45000.0
# 5        5    2451  Accountant         NaN  34.0  100000.0
# 6        6    1111  Accountant    Accounts   NaN  110000.0
# 7        7    1001     Officer          IT  25.0   75000.0
# 8        8    1234     Manager          IT  23.0       NaN
# 9        9    2156    Engineer  Production  45.0   89000.0
# 10      10    6543     Officer  Production  29.0  100000.0
# 11      11    3214  Accountant     Account  49.0  123000.0
# 12      12    2156    Engineer  Production  45.0   89000.0
# 13      13    1098     Officer          IT  25.0  100000.0
# 14      14    2912     Officer          IT  31.0   90000.0
# ...

# %%
int(data.shape[1]*.95)
# Out:
# 5

# %%
data.dropna(axis=0, thresh=int(data.shape[1]*0.95))
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        0    1101     Manager    Accounts  50.0  200000.0
# 1        1    1107     Officer          IT  30.0   80000.0
# 2        2    1203     Officer          HR  28.0       NaN
# 3        3    1005     Manager          HR  45.0  120000.0
# 4        4    2123  Office Boy    Accounts  27.0   45000.0
# 5        5    2451  Accountant         NaN  34.0  100000.0
# 6        6    1111  Accountant    Accounts   NaN  110000.0
# 7        7    1001     Officer          IT  25.0   75000.0
# 8        8    1234     Manager          IT  23.0       NaN
# 9        9    2156    Engineer  Production  45.0   89000.0
# 10      10    6543     Officer  Production  29.0  100000.0
# 11      11    3214  Accountant     Account  49.0  123000.0
# 12      12    2156    Engineer  Production  45.0   89000.0
# 13      13    1098     Officer          IT  25.0  100000.0
# 14      14    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.iloc[15]
# Out:
# Serial              15
# Emp_ID            1222
# Designation    Officer
# Department         NaN
# Age               25.0
# Salary             NaN
# Name: 15, dtype: object

# %% [markdown]
# #### Fill the missing Data

# %%
data.fillna(1000)
# Out:
#     Serial  Emp_ID Designation  Department     Age    Salary
# 0        0    1101     Manager    Accounts    50.0  200000.0
# 1        1    1107     Officer          IT    30.0   80000.0
# 2        2    1203     Officer          HR    28.0    1000.0
# 3        3    1005     Manager          HR    45.0  120000.0
# 4        4    2123  Office Boy    Accounts    27.0   45000.0
# 5        5    2451  Accountant        1000    34.0  100000.0
# 6        6    1111  Accountant    Accounts  1000.0  110000.0
# 7        7    1001     Officer          IT    25.0   75000.0
# 8        8    1234     Manager          IT    23.0    1000.0
# 9        9    2156    Engineer  Production    45.0   89000.0
# 10      10    6543     Officer  Production    29.0  100000.0
# 11      11    3214  Accountant     Account    49.0  123000.0
# 12      12    2156    Engineer  Production    45.0   89000.0
# 13      13    1098     Officer          IT    25.0  100000.0
# ...

# %%
data.Age
# Out:
# 0     50.0
# 1     30.0
# 2     28.0
# 3     45.0
# 4     27.0
# 5     34.0
# 6      NaN
# 7     25.0
# 8     23.0
# 9     45.0
# 10    29.0
# 11    49.0
# 12    45.0
# 13    25.0
# 14    31.0
# 15    25.0
# 16    45.0
# 17    27.0
# 18    45.0
# 19    27.0
# 20    29.0
# 21    49.0
# 22    45.0
# 23    25.0
# 24    45.0
# 25    27.0
# Name: Age, dtype: float64

# %%
data.Age.fillna(20)
# Out:
# 0     50.0
# 1     30.0
# 2     28.0
# 3     45.0
# 4     27.0
# 5     34.0
# 6     20.0
# 7     25.0
# 8     23.0
# 9     45.0
# 10    29.0
# 11    49.0
# 12    45.0
# 13    25.0
# 14    31.0
# 15    25.0
# 16    45.0
# 17    27.0
# 18    45.0
# 19    27.0
# 20    29.0
# 21    49.0
# 22    45.0
# 23    25.0
# 24    45.0
# 25    27.0
# Name: Age, dtype: float64

# %%
data.Age.fillna(data.Age.mean())
# Out:
# 0     50.0
# 1     30.0
# 2     28.0
# 3     45.0
# 4     27.0
# 5     34.0
# 6     35.0
# 7     25.0
# 8     23.0
# 9     45.0
# 10    29.0
# 11    49.0
# 12    45.0
# 13    25.0
# 14    31.0
# 15    25.0
# 16    45.0
# 17    27.0
# 18    45.0
# 19    27.0
# 20    29.0
# 21    49.0
# 22    45.0
# 23    25.0
# 24    45.0
# 25    27.0
# Name: Age, dtype: float64

# %%
data.Department
# Out:
# 0       Accounts
# 1             IT
# 2             HR
# 3             HR
# 4       Accounts
# 5            NaN
# 6       Accounts
# 7             IT
# 8             IT
# 9     Production
# 10    Production
# 11       Account
# 12    Production
# 13            IT
# 14            IT
# 15           NaN
# 16    Production
# 17      Accounts
# 18            HR
# 19      Accounts
# 20    Production
# 21       Account
# 22    Production
# 23            IT
# 24    Production
# 25      Accounts
# Name: Department, dtype: object

# %%
data.Department.mode()
# Out:
# 0    Production
# Name: Department, dtype: object

# %%
data.Department.mode()[0]
# Out:
# 'Production'

# %%
data.Department.fillna(data.Department.mode()[0])
# Out:
# 0       Accounts
# 1             IT
# 2             HR
# 3             HR
# 4       Accounts
# 5     Production
# 6       Accounts
# 7             IT
# 8             IT
# 9     Production
# 10    Production
# 11       Account
# 12    Production
# 13            IT
# 14            IT
# 15    Production
# 16    Production
# 17      Accounts
# 18            HR
# 19      Accounts
# 20    Production
# 21       Account
# 22    Production
# 23            IT
# 24    Production
# 25      Accounts
# Name: Department, dtype: object

# %%
data.Department.mode()[0]
# Out:
# 'Production'

# %%
data.Salary
# Out:
# 0     200000.0
# 1      80000.0
# 2          NaN
# 3     120000.0
# 4      45000.0
# 5     100000.0
# 6     110000.0
# 7      75000.0
# 8          NaN
# 9      89000.0
# 10    100000.0
# 11    123000.0
# 12     89000.0
# 13    100000.0
# 14     90000.0
# 15         NaN
# 16     89000.0
# 17     45000.0
# 18    120000.0
# 19     45000.0
# 20    100000.0
# 21    123000.0
# 22     89000.0
# 23    100000.0
# 24     89000.0
# 25     45000.0
# Name: Salary, dtype: float64

# %%
data.Salary.fillna(data.Salary.mean())
# Out:
# 0     200000.000000
# 1      80000.000000
# 2      94173.913043
# 3     120000.000000
# 4      45000.000000
# 5     100000.000000
# 6     110000.000000
# 7      75000.000000
# 8      94173.913043
# 9      89000.000000
# 10    100000.000000
# 11    123000.000000
# 12     89000.000000
# 13    100000.000000
# 14     90000.000000
# 15     94173.913043
# 16     89000.000000
# 17     45000.000000
# 18    120000.000000
# 19     45000.000000
# 20    100000.000000
# 21    123000.000000
# 22     89000.000000
# 23    100000.000000
# 24     89000.000000
# 25     45000.000000
# Name: Salary, dtype: float64

# %%
data.fillna({'Age':data.Age.mean(), 'Department':data.Department.mode()[0], 'Salary':data.Salary.mean()},inplace=True)

# %%
import numpy as np
sal = np.array([43,45,50,60,55,44,35,30,400,430,60])

# %%
sal.mean()
# Out:
# 113.81818181818181

# %%
np.median(sal)
# Out:
# 50.0

# %%
sal.sort()

# %%
sal
# Out:
# array([ 30,  35,  43,  44,  45,  50,  55,  60,  60, 400, 430])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(data.Salary)
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
# https://www.geeksforgeeks.org/data-analysis/box-plot/

# %%
 # Updated data ko Excel file mein save karne ke liye
data.to_excel('emp.xlsx', index=False)
